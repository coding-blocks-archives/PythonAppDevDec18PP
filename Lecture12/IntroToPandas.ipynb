# %% [markdown]
# # <center>Introduction to Pandas</center>
#
# ![](https://pandas.pydata.org/_static/pandas_logo.png)
#
# >pandas is an open source, BSD-licensed library providing **high-performance**, **easy-to-use data structures** and **data analysis tools** for the Python programming language.  Pandas stands for “Python Data Analysis Library”. According to the Wikipedia page on Pandas, “the name is derived from the term “panel data”, an econometrics term for multidimensional structured data sets.”
#
# ## Why use Pandas?
#
# What’s cool about Pandas is that it takes data (like a CSV or TSV file, or a SQL database) and creates a Python object with rows and columns called **data frame** that looks very similar to table in a statistical software (think Excel). This is so much easier to work with in comparison to working with lists and/or dictionaries through for loops or list comprehension!
#
# So, in a way:
#
# # <center>ARRAY + TABLE = PANDAS</center>
#
# ![](https://memegenerator.net/img/instances/500x/51740682/you-are-a-python-lover-if-pandas-doesnt-mean-but-httppandaspydataorg.jpg)

# %% [markdown]
# ## Installation
#
# Simply,
# ```
# pip install pandas
# ```

# %% [markdown]
# ## Reading data from a CSV file
#
# You can read data from a CSV file using the ``read_csv`` function. By default, it assumes that the fields are comma-separated.

# %%
import pandas as pd

# %%
imdb_df = pd.read_csv("data/imdb_1000.csv")

# %%
imdb_df.head(6)
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
# 5          8.9              12 Angry Men      NOT RATED   Drama        96
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...

# %%
bikes_df = pd.read_csv("data/bikes.csv", sep=';', parse_dates=['Date'], index_col='Date', dayfirst=True)

# %%
bikes_df.head()
# Out:
#            Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# Date
# 2012-01-01      00:00                 16      35             51
# 2012-01-02      00:00                 43      83            153
# 2012-01-03      00:00                 58     135            248
# 2012-01-04      00:00                 61     144            318
# 2012-01-05      00:00                 95     197            330
#
#             Maisonneuve_1  Brébeuf  Parc  PierDup  \
# Date
# 2012-01-01             38      5.0    26       10
# 2012-01-02             68     11.0    53        6
# 2012-01-03            104      2.0    89        3
# 2012-01-04            116      2.0   111        8
# 2012-01-05            124      6.0    97       13
#
#             CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# Date
# 2012-01-01                            0                  27.0
# 2012-01-02                            1                  21.0
# 2012-01-03                            2                  15.0
# ...

# %%
bikes_df = pd.read_csv("data/bikes.csv", sep=';', parse_dates=['Date'], dayfirst=True, index_col='Date')

# %%
bikes_df.head()
# Out:
#            Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# Date
# 01/01/2012      00:00                 16      35             51
# 02/01/2012      00:00                 43      83            153
# 03/01/2012      00:00                 58     135            248
# 04/01/2012      00:00                 61     144            318
# 05/01/2012      00:00                 95     197            330
#
#             Maisonneuve_1  Brébeuf  Parc  PierDup  \
# Date
# 01/01/2012             38      5.0    26       10
# 02/01/2012             68     11.0    53        6
# 03/01/2012            104      2.0    89        3
# 04/01/2012            116      2.0   111        8
# 05/01/2012            124      6.0    97       13
#
#             CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# Date
# 01/01/2012                            0                  27.0
# 02/01/2012                            1                  21.0
# 03/01/2012                            2                  15.0
# ...

# %%
type(bikes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
bikes_df.columns
# Out:
# Index(['Unnamed: 1', 'Rachel / Papineau', 'Berri1', 'Maisonneuve_2',
#        'Maisonneuve_1', 'Brébeuf', 'Parc', 'PierDup',
#        'CSC (Côte Sainte-Catherine)', 'Pont_Jacques_Cartier'],
#       dtype='object')

# %%
imdb_df.index
# Out:
# RangeIndex(start=0, stop=979, step=1)

# %%
bikes_df.index
# Out:
# DatetimeIndex(['2012-01-01', '2012-01-02', '2012-01-03', '2012-01-04',
#                '2012-01-05', '2012-01-06', '2012-01-07', '2012-01-08',
#                '2012-01-09', '2012-01-10',
#                ...
#                '2012-12-22', '2012-12-23', '2012-12-24', '2012-12-25',
#                '2012-12-26', '2012-12-27', '2012-12-28', '2012-12-29',
#                '2012-12-30', '2012-12-31'],
#               dtype='datetime64[ns]', name='Date', length=366, freq=None)

# %%
bikes_df.dtypes
# Out:
# Unnamed: 1                      object
# Rachel / Papineau                int64
# Berri1                           int64
# Maisonneuve_2                    int64
# Maisonneuve_1                    int64
# Brébeuf                        float64
# Parc                             int64
# PierDup                          int64
# CSC (Côte Sainte-Catherine)      int64
# Pont_Jacques_Cartier           float64
# dtype: object

# %% [markdown]
# ## Creating dataframe
#
# A list of lists/tuples can be used to create a DataFrame.

# %%
# The inital set of baby names and bith rates
names = ['Bob','Jessica','Mary','John','Mel']
births = [968, 155, 77, 578, 973]

# %%
BabyDataSet = list(zip(names,births))

# %%
BabyDataSet
# Out:
# [('Bob', 968), ('Jessica', 155), ('Mary', 77), ('John', 578), ('Mel', 973)]

# %%
df = pd.DataFrame(data = BabyDataSet, columns=['Names', 'Births'], 
                  index=range(1, len(BabyDataSet)+1))

# %%
df.head()
# Out:
#      Names  Births
# 1      Bob     968
# 2  Jessica     155
# 3     Mary      77
# 4     John     578
# 5      Mel     973

# %%
# saving dataframe as csv file
df.to_csv('data/births.csv', index=False)

# %%
df = pd.read_csv("data/births.csv")

# %%
df
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     578
# 4      Mel     973

# %% [markdown]
# ## Selecting columns
#
# When you read a CSV, you get a kind of object called a DataFrame, which is made up of rows and columns. You get columns out of a DataFrame the same way you get elements out of a dictionary.

# %%
imdb_df.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
imdb_df['title']
# Out:
# 0                               The Shawshank Redemption
# 1                                          The Godfather
# 2                                 The Godfather: Part II
# 3                                        The Dark Knight
# 4                                           Pulp Fiction
# 5                                           12 Angry Men
# 6                         The Good, the Bad and the Ugly
# 7          The Lord of the Rings: The Return of the King
# 8                                       Schindler's List
# 9                                             Fight Club
# 10     The Lord of the Rings: The Fellowship of the Ring
# 11                                             Inception
# 12        Star Wars: Episode V - The Empire Strikes Back
# 13                                          Forrest Gump
# 14                 The Lord of the Rings: The Two Towers
# 15                                          Interstellar
# ...

# %%
type(imdb_df['title'])
# Out:
# pandas.core.series.Series

# %%
imdb_df['title'].index
# Out:
# RangeIndex(start=0, stop=979, step=1)

# %%
imdb_df['title'].values
# Out:
# array(['The Shawshank Redemption', 'The Godfather',
#        'The Godfather: Part II', 'The Dark Knight', 'Pulp Fiction',
#        '12 Angry Men', 'The Good, the Bad and the Ugly',
#        'The Lord of the Rings: The Return of the King',
#        "Schindler's List", 'Fight Club',
#        'The Lord of the Rings: The Fellowship of the Ring', 'Inception',
#        'Star Wars: Episode V - The Empire Strikes Back', 'Forrest Gump',
#        'The Lord of the Rings: The Two Towers', 'Interstellar',
#        "One Flew Over the Cuckoo's Nest", 'Seven Samurai', 'Goodfellas',
#        'Star Wars', 'The Matrix', 'City of God', "It's a Wonderful Life",
#        'The Usual Suspects', 'Se7en', 'Life Is Beautiful',
#        'Once Upon a Time in the West', 'The Silence of the Lambs',
#        'Leon: The Professional', 'City Lights', 'Spirited Away',
#        'The Intouchables', 'Casablanca', 'Whiplash', 'American History X',
#        'Modern Times', 'Saving Private Ryan', 'Raiders of the Lost Ark',
# ...

# %%
bikes_df['Berri1'].index
# Out:
# DatetimeIndex(['2012-01-01', '2012-01-02', '2012-01-03', '2012-01-04',
#                '2012-01-05', '2012-01-06', '2012-01-07', '2012-01-08',
#                '2012-01-09', '2012-01-10',
#                ...
#                '2012-12-22', '2012-12-23', '2012-12-24', '2012-12-25',
#                '2012-12-26', '2012-12-27', '2012-12-28', '2012-12-29',
#                '2012-12-30', '2012-12-31'],
#               dtype='datetime64[ns]', name='Date', length=366, freq=None)

# %%
# selecting multiple columns at once
imdb_df[['star_rating', 'genre']].plot()

# %% [markdown]
# ## Understanding columns
#
# On the inside, the type of a column is ``pd.Series`` and pandas Series are internally numpy arrays. If you add ``.values`` to the end of any Series, you'll get its internal **numpy array**.

# %%
durations = imdb_df['duration']

# %%
type(durations)
# Out:
# pandas.core.series.Series

# %%
type(durations.values)
# Out:
# numpy.ndarray

# %%
duration_arr = durations.values

# %%
duration_arr[:5]
# Out:
# array([142, 175, 200, 152, 154])

# %% [markdown]
# ## Applying functions to columns

# %%
imdb_df['title'] = imdb_df['title'].apply(lambda x: x.upper())

# %%
imdb_df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  THE SHAWSHANK REDEMPTION              R   Crime       142
# 1          9.2             THE GODFATHER              R   Crime       175
# 2          9.1    THE GODFATHER: PART II              R   Crime       200
# 3          9.0           THE DARK KNIGHT          PG-13  Action       152
# 4          8.9              PULP FICTION              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# ## Plotting a column
#
# Use ``.plot()`` function!

# %%
# %matplotlib inline

# %%
bikes_df['Berri1']
# Out:
# Date
# 2012-01-01      35
# 2012-01-02      83
# 2012-01-03     135
# 2012-01-04     144
# 2012-01-05     197
# 2012-01-06     146
# 2012-01-07      98
# 2012-01-08      95
# 2012-01-09     244
# 2012-01-10     397
# 2012-01-11     273
# 2012-01-12     157
# 2012-01-13      75
# 2012-01-14      32
# 2012-01-15      54
# 2012-01-16     168
# 2012-01-17     155
# 2012-01-18     139
# 2012-01-19     191
# 2012-01-20     161
# 2012-01-21      53
# 2012-01-22      71
# 2012-01-23     210
# 2012-01-24     299
# 2012-01-25     334
# 2012-01-26     306
# 2012-01-27      91
# 2012-01-28      80
# 2012-01-29      87
# 2012-01-30     219
#               ...
# 2012-12-02     324
# 2012-12-03    1286
# 2012-12-04    1264
# 2012-12-05    1204
# 2012-12-06    1252
# 2012-12-07    1151
# 2012-12-08     382
# 2012-12-09     427
# 2012-12-10     245
# 2012-12-11     517
# 2012-12-12     598
# 2012-12-13     655
# 2012-12-14     738
# 2012-12-15     335
# 2012-12-16     177
# 2012-12-17     236
# ...

# %%
import matplotlib.pyplot as plt

# %%
x = bikes_df['Berri1'].index
y = bikes_df['Berri1'].values

# %%
plt.plot(x,y)

# %%
bikes_df['Berri1'].plot()

# %% [markdown]
# We can also plot all the columns just as easily.

# %%
bikes_df.plot(figsize=(15, 10))

# %% [markdown]
# ## Index
#
# ### DATAFRAME = COLUMNS + INDEX + ND DATA
#
# ### SERIES = INDEX + 1-D DATA
#
# **Index** or (**row labels**) is one of the fundamental data structure of pandas. It can be thought of as an **immutable array** and an **ordered set**.
#
# > Every row is uniquely identified by its index value.

# %%
bikes_df.index
# Out:
# DatetimeIndex(['2012-01-01', '2012-01-02', '2012-01-03', '2012-01-04',
#                '2012-01-05', '2012-01-06', '2012-01-07', '2012-01-08',
#                '2012-01-09', '2012-01-10',
#                ...
#                '2012-12-22', '2012-12-23', '2012-12-24', '2012-12-25',
#                '2012-12-26', '2012-12-27', '2012-12-28', '2012-12-29',
#                '2012-12-30', '2012-12-31'],
#               dtype='datetime64[ns]', name='Date', length=366, freq=None)

# %%
# get row for date 2012-01-01
bikes_df.loc['2012-01-01']
# Out:
# Unnamed: 1                     00:00
# Rachel / Papineau                 16
# Berri1                            35
# Maisonneuve_2                     51
# Maisonneuve_1                     38
# Brébeuf                            5
# Parc                              26
# PierDup                           10
# CSC (Côte Sainte-Catherine)        0
# Pont_Jacques_Cartier              27
# Name: 2012-01-01 00:00:00, dtype: object

# %%
bikes_df['Berri1'].loc['2012-01-01']
# Out:
# 35

# %% [markdown]
# #### To get row by integer index:
#
# Use ``.iloc[]`` for purely integer-location based indexing for selection by position.

# %%
bikes_df.iloc[0]
# Out:
# Unnamed: 1                     00:00
# Rachel / Papineau                 16
# Berri1                            35
# Maisonneuve_2                     51
# Maisonneuve_1                     38
# Brébeuf                            5
# Parc                              26
# PierDup                           10
# CSC (Côte Sainte-Catherine)        0
# Pont_Jacques_Cartier              27
# Name: 2012-01-01 00:00:00, dtype: object

# %%
bikes_df['Berri1'][0]
# Out:
# 35

# %% [markdown]
# ## Slicing of dataframe

# %%
imdb_df[['title', 'genre']].head()
# Out:
#                       title   genre
# 0  THE SHAWSHANK REDEMPTION   Crime
# 1             THE GODFATHER   Crime
# 2    THE GODFATHER: PART II   Crime
# 3           THE DARK KNIGHT  Action
# 4              PULP FICTION   Crime

# %%
# fetch first 5 rows of dataframe
bikes_df[:5]
# Out:
#            Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# Date
# 2012-01-01      00:00                 16      35             51
# 2012-01-02      00:00                 43      83            153
# 2012-01-03      00:00                 58     135            248
# 2012-01-04      00:00                 61     144            318
# 2012-01-05      00:00                 95     197            330
#
#             Maisonneuve_1  Brébeuf  Parc  PierDup  \
# Date
# 2012-01-01             38      5.0    26       10
# 2012-01-02             68     11.0    53        6
# 2012-01-03            104      2.0    89        3
# 2012-01-04            116      2.0   111        8
# 2012-01-05            124      6.0    97       13
#
#             CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# Date
# 2012-01-01                            0                  27.0
# 2012-01-02                            1                  21.0
# 2012-01-03                            2                  15.0
# ...

# %%
# fetch first 5 rows of a specific column
bikes_df['Berri1'][:5]
# Out:
# Date
# 2012-01-01     35
# 2012-01-02     83
# 2012-01-03    135
# 2012-01-04    144
# 2012-01-05    197
# Name: Berri1, dtype: int64

# %% [markdown]
# ## Value counts
#
# Get count of unique values in a particular column/Series.

# %%
imdb_df['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
x = imdb_df['genre'].value_counts()

# %%
# plotting value counts as a bar chart
x.plot(kind='pie')

# %% [markdown]
# # Selecting rows where column has a particular value

# %%
import numpy as np

# %%
arr = np.array([[-1,2,1],
               [3,0,-2],
               [1,0,-5]])

# %%
arr[arr > 0]
# Out:
# array([2, 1, 3, 1])

# %%
imdb_df['genre'] == 'Adventure'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7       True
# 8      False
# 9      False
# 10      True
# 11     False
# 12     False
# 13     False
# 14      True
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 949    False
# 950    False
# 951    False
# 952    False
# 953     True
# 954    False
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963    False
# 964    False
# 965    False
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975     True
# 976    False
# 977    False
# 978    False
# Name: genre, Length: 979, dtype: bool

# %%
# select only those movies where genre is adventure
adventure_movies = imdb_df[imdb_df['genre'] == 'Adventure']

# %%
adventure_movies.head()
# Out:
#     star_rating                                              title  \
# 7           8.9      THE LORD OF THE RINGS: THE RETURN OF THE KING
# 10          8.8  THE LORD OF THE RINGS: THE FELLOWSHIP OF THE RING
# 14          8.8              THE LORD OF THE RINGS: THE TWO TOWERS
# 15          8.7                                       INTERSTELLAR
# 54          8.5                                 BACK TO THE FUTURE
#
#    content_rating      genre  duration  \
# 7           PG-13  Adventure       201
# 10          PG-13  Adventure       178
# 14          PG-13  Adventure       179
# 15          PG-13  Adventure       169
# 54             PG  Adventure       116
#
#                                           actors_list
# 7   [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 10  [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 14  [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# 15  [u'Matthew McConaughey', u'Anne Hathaway', u'J...
# ...

# %%
imdb_df[imdb_df['duration'] > 200]['title'].values
# Out:
# array(['THE LORD OF THE RINGS: THE RETURN OF THE KING', 'SEVEN SAMURAI',
#        'ONCE UPON A TIME IN AMERICA', 'LAWRENCE OF ARABIA',
#        'LAGAAN: ONCE UPON A TIME IN INDIA', 'GONE WITH THE WIND',
#        'BEN-HUR', 'THE TEN COMMANDMENTS', 'HAMLET', 'MALCOLM X',
#        "IT'S A MAD, MAD, MAD, MAD WORLD"], dtype=object)

# %%
good_adventure_movies = imdb_df[(imdb_df['genre'] == 'Adventure') & (imdb_df['star_rating'] > 8.4)]

# %%
good_adventure_movies
# Out:
#     star_rating                                              title  \
# 7           8.9      THE LORD OF THE RINGS: THE RETURN OF THE KING
# 10          8.8  THE LORD OF THE RINGS: THE FELLOWSHIP OF THE RING
# 14          8.8              THE LORD OF THE RINGS: THE TWO TOWERS
# 15          8.7                                       INTERSTELLAR
# 54          8.5                                 BACK TO THE FUTURE
#
#    content_rating      genre  duration  \
# 7           PG-13  Adventure       201
# 10          PG-13  Adventure       178
# 14          PG-13  Adventure       179
# 15          PG-13  Adventure       169
# 54             PG  Adventure       116
#
#                                           actors_list
# 7   [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 10  [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 14  [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# 15  [u'Matthew McConaughey', u'Anne Hathaway', u'J...
# ...

# %%
# organised way
is_adventure = imdb_df['genre'] == 'Adventure'
has_high_rating = imdb_df['star_rating'] > 8.4
good_adventure_movies = imdb_df[is_adventure & has_high_rating]

# Just see title and duration of good adventure movies
good_adventure_movies[['title', 'duration']]
# Out:
#                                                 title  duration
# 7       THE LORD OF THE RINGS: THE RETURN OF THE KING       201
# 10  THE LORD OF THE RINGS: THE FELLOWSHIP OF THE RING       178
# 14              THE LORD OF THE RINGS: THE TWO TOWERS       179
# 15                                       INTERSTELLAR       169
# 54                                 BACK TO THE FUTURE       116

# %%
# which genre has highest number of movies with star rating above 8?
has_above_8_rating = imdb_df['star_rating'] >= 8.0
good_movies = imdb_df[has_above_8_rating]
good_movies_genre_count = good_movies['genre'].value_counts()

# %%
good_movies_genre_count
# Out:
# Drama        124
# Crime         51
# Comedy        50
# Action        47
# Adventure     37
# Animation     27
# Biography     26
# Horror        10
# Mystery        9
# Western        7
# Film-Noir      2
# Sci-Fi         2
# History        1
# Thriller       1
# Name: genre, dtype: int64

# %%
good_movies_genre_count.idxmax()
# Out:
# 'Drama'

# %%
x = imdb_df['genre'].value_counts()

# %%
y = imdb_df[imdb_df['star_rating'] >= 8.4]['genre'].value_counts()

# %%
x
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
y
# Out:
# Drama        28
# Crime        18
# Action       14
# Comedy       12
# Adventure     8
# Animation     6
# Biography     5
# Western       3
# Horror        3
# Mystery       3
# Name: genre, dtype: int64

# %%
z = []

# %%
for idx,val in y.items():
    z.append((idx, round((val/x.loc[idx])*100,2)))

# %%
idx, vals = list(zip(*z))

# %%
pd.Series(vals, index=idx).plot(kind='bar')

# %% [markdown]
# ## Adding a new column to DataFrame

# %%
weekdays = bikes_df.index.weekday

# %%
weekdays
# Out:
# Int64Index([6, 0, 1, 2, 3, 4, 5, 6, 0, 1,
#             ...
#             5, 6, 0, 1, 2, 3, 4, 5, 6, 0],
#            dtype='int64', name='Date', length=366)

# %%
bikes_df['weekday'] = weekdays

# %%
bikes_df.head()
# Out:
#            Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# Date
# 2012-01-01      00:00                 16      35             51
# 2012-01-02      00:00                 43      83            153
# 2012-01-03      00:00                 58     135            248
# 2012-01-04      00:00                 61     144            318
# 2012-01-05      00:00                 95     197            330
#
#             Maisonneuve_1  Brébeuf  Parc  PierDup  \
# Date
# 2012-01-01             38      5.0    26       10
# 2012-01-02             68     11.0    53        6
# 2012-01-03            104      2.0    89        3
# 2012-01-04            116      2.0   111        8
# 2012-01-05            124      6.0    97       13
#
#             CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier  weekday
# Date
# 2012-01-01                            0                  27.0        6
# 2012-01-02                            1                  21.0        0
# ...

# %% [markdown]
# ## Deleting an existing column from DataFrame

# %%
bikes_df.head()
# Out:
#             Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# Date
# 2012-01-01                 16      35             51             38      5.0
# 2012-01-02                 43      83            153             68     11.0
# 2012-01-03                 58     135            248            104      2.0
# 2012-01-04                 61     144            318            116      2.0
# 2012-01-05                 95     197            330            124      6.0
#
#             Parc  PierDup  CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier  \
# Date
# 2012-01-01    26       10                            0                  27.0
# 2012-01-02    53        6                            1                  21.0
# 2012-01-03    89        3                            2                  15.0
# 2012-01-04   111        8                            1                  19.0
# 2012-01-05    97       13                            2                  16.0
#
#             weekday
# ...

# %%
bikes_df.drop('Unnamed: 1', axis=1)
# Out:
#             Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# Date
# 2012-01-01                 16      35             51             38      5.0
# 2012-01-02                 43      83            153             68     11.0
# 2012-01-03                 58     135            248            104      2.0
# 2012-01-04                 61     144            318            116      2.0
# 2012-01-05                 95     197            330            124      6.0
# 2012-01-06                 75     146            244             98      4.0
# 2012-01-07                 54      98            108             80      5.0
# 2012-01-08                 63      95             98             62     13.0
# 2012-01-09                173     244            432            165      9.0
# 2012-01-10                241     397            563            238      6.0
# 2012-01-11                194     273            443            182      7.0
# ...

# %%
bikes_df.drop('Unnamed: 1', axis=1, inplace=True)

# %%
# deleting column no. 1, 2, and 3
bikes_df.drop(bikes_df.columns[[1,2,3]], axis=1)
# Out:
#             Rachel / Papineau  Brébeuf  Parc  PierDup  \
# Date
# 2012-01-01                 16      5.0    26       10
# 2012-01-02                 43     11.0    53        6
# 2012-01-03                 58      2.0    89        3
# 2012-01-04                 61      2.0   111        8
# 2012-01-05                 95      6.0    97       13
# 2012-01-06                 75      4.0    86        4
# 2012-01-07                 54      5.0    53        6
# 2012-01-08                 63     13.0    64       11
# 2012-01-09                173      9.0   198       12
# 2012-01-10                241      6.0   275       18
# 2012-01-11                194      7.0   258       12
# 2012-01-12                 63      3.0   137        9
# 2012-01-13                  0      4.0    64        2
# 2012-01-14                  1      0.0    19        0
# 2012-01-15                  0      0.0    18        0
# 2012-01-16                  0      8.0   137        1
# ...

# %% [markdown]
# ## Deleting a row in DataFrame

# %%
df
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     578
# 4      Mel     973

# %%
df.drop(df.index[0])

# %%
bikes_df.head()
# Out:
#             Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# Date
# 2012-01-01                 16      35             51             38      5.0
# 2012-01-02                 43      83            153             68     11.0
# 2012-01-03                 58     135            248            104      2.0
# 2012-01-04                 61     144            318            116      2.0
# 2012-01-05                 95     197            330            124      6.0
#
#             Parc  PierDup  CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier  \
# Date
# 2012-01-01    26       10                            0                  27.0
# 2012-01-02    53        6                            1                  21.0
# 2012-01-03    89        3                            2                  15.0
# 2012-01-04   111        8                            1                  19.0
# 2012-01-05    97       13                            2                  16.0
#
#             weekday
# ...

# %%
bikes_df.index[0]
# Out:
# Timestamp('2012-01-01 00:00:00')

# %%
bikes_df.drop(bikes_df.index[:50], axis=0)
# Out:
#             Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# Date
# 2012-02-20                 10     303            470            224     17.0
# 2012-02-21                  6     441            503            292     12.0
# 2012-02-22                  3     375            501            263      7.0
# 2012-02-23                 13     397            528            293     12.0
# 2012-02-24                 13     243            313            187     13.0
# 2012-02-25                  5      62             52             48      1.0
# 2012-02-26                  0      78             47             76      2.0
# 2012-02-27                  5     119            298             94      9.0
# 2012-02-28                  3     195            350            158     22.0
# 2012-02-29                  4     242            446            164     15.0
# 2012-03-01                 14      92            199             56     46.0
# ...

# %%
df.drop([0,1,2])
# Out:
#   Names  Births
# 3  John     578
# 4   Mel     973

# %%
# drop movies with rating less than 9.0
has_poor_rating = imdb_df['star_rating'] < 9.0
imdb_df.drop(imdb_df[has_poor_rating].index)
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  THE SHAWSHANK REDEMPTION              R   Crime       142
# 1          9.2             THE GODFATHER              R   Crime       175
# 2          9.1    THE GODFATHER: PART II              R   Crime       200
# 3          9.0           THE DARK KNIGHT          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %% [markdown]
# ## Group By
#
# Any groupby operation involves one of the following operations on the original object. They are −
#
# - Splitting the Object
#
# - Applying a function
#
# - Combining the results
#
# In many situations, we split the data into sets and we apply some functionality on each subset. In the apply functionality, we can perform the following operations −
#
# - **Aggregation** − computing a summary statistic
#
# - **Transformation** − perform some group-specific operation
#
# - **Filtration** − discarding the data with some condition

# %%
genre_groups = imdb_df.groupby('genre')

# %%
type(genre_groups)
# Out:
# pandas.core.groupby.groupby.DataFrameGroupBy

# %%
genre_groups.get_group('Adventure')
# Out:
#      star_rating                                              title  \
# 7            8.9      THE LORD OF THE RINGS: THE RETURN OF THE KING
# 10           8.8  THE LORD OF THE RINGS: THE FELLOWSHIP OF THE RING
# 14           8.8              THE LORD OF THE RINGS: THE TWO TOWERS
# 15           8.7                                       INTERSTELLAR
# 54           8.5                                 BACK TO THE FUTURE
# 68           8.4                                           DAS BOOT
# 71           8.4                                 NORTH BY NORTHWEST
# 85           8.4                                 LAWRENCE OF ARABIA
# 101          8.3                    MONTY PYTHON AND THE HOLY GRAIL
# 114          8.3                               INGLOURIOUS BASTERDS
# 120          8.3                                   THE GREAT ESCAPE
# 128          8.3                                      THE GOLD RUSH
# 133          8.3                                             BARFI!
# ...

# %%
weekday_groups = bikes_df.groupby('weekday')

# %%
weekday_groups.get_group(0)
# Out:
#             Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# Date
# 2012-01-02                 43      83            153             68     11.0
# 2012-01-09                173     244            432            165      9.0
# 2012-01-16                  0     168            312            136      8.0
# 2012-01-23                  0     210            357            114     22.0
# 2012-01-30                  0     219            371            146      6.0
# 2012-02-06                  0     248            425            136      5.0
# 2012-02-13                  0     211            408            175     13.0
# 2012-02-20                 10     303            470            224     17.0
# 2012-02-27                  5     119            298             94      9.0
# 2012-03-05                  2     155            363            114     88.0
# 2012-03-12                548     802           1265            618     12.0
# ...

# %%
weekday_counts = weekday_groups.aggregate(sum)

# %%
weekday_counts
# Out:
#          Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# weekday
# 0                   138881  142285         174610          95565  15436.0
# 1                   131632  145795         179939          99421  10629.0
# 2                   144531  163603         200273         112344  14876.0
# 3                   150971  169976         210039         118633  15679.0
# 4                   146979  150493         183961         104584  12259.0
# 5                   118560  105635         109902          64872  11170.0
# 6                   122115  102447         102272          57438  12032.0
#
#            Parc  PierDup  CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# weekday
# 0         97001    47259                        64011               74692.0
# 1        100007    35901                        63503               53552.0
# 2        110820    44045                        72047               63472.0
# ...

# %%
weekday_counts.index = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
weekday_counts
# Out:
#            Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# Monday                138881  142285         174610          95565  15436.0
# Tuesday               131632  145795         179939          99421  10629.0
# Wednesday             144531  163603         200273         112344  14876.0
# Thursday              150971  169976         210039         118633  15679.0
# Friday                146979  150493         183961         104584  12259.0
# Saturday              118560  105635         109902          64872  11170.0
# Sunday                122115  102447         102272          57438  12032.0
#
#              Parc  PierDup  CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# Monday      97001    47259                        64011               74692.0
# Tuesday    100007    35901                        63503               53552.0
# Wednesday  110820    44045                        72047               63472.0
# ...

# %%
weekday_counts['Berri1'].plot(kind='bar')

# %% [markdown]
# Let us see one more example!

# %%
genre_groups = imdb_df.groupby('genre')

# %%
# get crime movies group
genre_groups.get_group('Crime')
# Out:
#      star_rating                             title content_rating  genre  \
# 0            9.3          THE SHAWSHANK REDEMPTION              R  Crime
# 1            9.2                     THE GODFATHER              R  Crime
# 2            9.1            THE GODFATHER: PART II              R  Crime
# 4            8.9                      PULP FICTION              R  Crime
# 21           8.7                       CITY OF GOD              R  Crime
# 23           8.7                THE USUAL SUSPECTS              R  Crime
# 28           8.6            LEON: THE PROFESSIONAL              R  Crime
# 34           8.6                AMERICAN HISTORY X              R  Crime
# 40           8.5                    THE GREEN MILE              R  Crime
# 49           8.5                      THE DEPARTED              R  Crime
# 63           8.4                                 M      NOT RATED  Crime
# 65           8.4       WITNESS FOR THE PROSECUTION       APPROVED  Crime
# ...

# %%
import numpy as np

# %%
averages = genre_groups.aggregate(np.mean)

# %%
averages
# Out:
#            star_rating    duration
# genre
# Action        7.884559  126.485294
# Adventure     7.933333  134.840000
# Animation     7.914516   96.596774
# Biography     7.862338  131.844156
# Comedy        7.822436  107.602564
# Crime         7.916935  122.298387
# Drama         7.902518  126.539568
# Family        7.850000  107.500000
# Fantasy       7.700000  112.000000
# Film-Noir     8.033333   97.333333
# History       8.000000   66.000000
# Horror        7.806897  102.517241
# Mystery       7.975000  115.625000
# Sci-Fi        7.920000  109.000000
# Thriller      7.680000  114.200000
# Western       8.255556  136.666667

# %%
# get sum, mean and std-dev of movie durations for each group
duration_analysis = genre_groups['duration'].aggregate([np.sum, np.mean, np.std])

# %%
duration_analysis
# Out:
#              sum        mean        std
# genre
# Action     17202  126.485294  21.982480
# Adventure  10113  134.840000  33.383942
# Animation   5989   96.596774  13.975927
# Biography  10152  131.844156  24.283991
# Comedy     16786  107.602564  20.101574
# Crime      15165  122.298387  25.054406
# Drama      35178  126.539568  25.637086
# Family       215  107.500000  10.606602
# Fantasy      112  112.000000        NaN
# Film-Noir    292   97.333333  12.096832
# History       66   66.000000        NaN
# Horror      2973  102.517241  18.908843
# Mystery     1850  115.625000  22.585762
# Sci-Fi       545  109.000000  17.478558
# Thriller     571  114.200000   6.340347
# Western     1230  136.666667  28.748913

# %%
# change duration of all movies in a particular genre to mean duration of the group
averaged_movie_durations = genre_groups['duration'].transform(lambda x:x.mean())

# %%
# drop groups/genres that do not have average movie duration greater than 120.
genre_groups.filter(lambda x: x['duration'].mean() > 120)['genre'].value_counts()
# Out:
# Drama        278
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Western        9
# Name: genre, dtype: int64

# %% [markdown]
# ## Exercises:
#
# https://github.com/guipsamora/pandas_exercises/
#
# Practice pandas using these exercises. Every exercise has 3 notebooks:
# - Exercise
# - Solutions
# - Exercise with solutions

# %%
matches_df = pd.read_csv("data/matches.csv", index_col='id')

# %%
matches_df.head()
# Out:
#     season       city        date                        team1  \
# id
# 1     2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2     2017       Pune  2017-04-06               Mumbai Indians
# 3     2017     Rajkot  2017-04-07                Gujarat Lions
# 4     2017     Indore  2017-04-08       Rising Pune Supergiant
# 5     2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Rising Pune Supergiant       Rising Pune Supergiant         field
# 3         Kolkata Knight Riders        Kolkata Knight Riders         field
# 4               Kings XI Punjab              Kings XI Punjab         field
# 5              Delhi Daredevils  Royal Challengers Bangalore           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# id
# ...

# %%
matches_df.query("season == 2018").player_of_match.value_counts()
# Out:
# Rashid Khan       4
# SP Narine         3
# AB de Villiers    3
# SR Watson         3
# JC Buttler        3
# KS Williamson     2
# KL Rahul          2
# CA Lynn           2
# SV Samson         2
# CH Gayle          2
# S Dhawan          2
# AT Rayudu         2
# RG Sharma         2
# AS Rajpoot        2
# UT Yadav          2
# N Rana            2
# J Archer          1
# Kuldeep Yadav     1
# AD Russell        1
# TG Southee        1
# A Mishra          1
# HV Patel          1
# AS Yadav          1
# SW Billings       1
# HH Pandya         1
# DJ Bravo          1
# JJ Bumrah         1
# RA Jadeja         1
# JJ Roy            1
# S Gopal           1
# M Ur Rahman       1
# Ishan Kishan      1
# MS Dhoni          1
# F du Plessis      1
# L Ngidi           1
# RR Pant           1
# B Stanlake        1
# SS Iyer           1
# Name: player_of_match, dtype: int64

# %%
matches_df.query("toss_winner != winner")['toss_winner'].value_counts()
# Out:
# Delhi Daredevils               45
# Kings XI Punjab                43
# Mumbai Indians                 40
# Kolkata Knight Riders          38
# Royal Challengers Bangalore    38
# Rajasthan Royals               32
# Chennai Super Kings            27
# Deccan Chargers                24
# Sunrisers Hyderabad            21
# Pune Warriors                  17
# Gujarat Lions                   5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         4
# Rising Pune Supergiant          1
# Name: toss_winner, dtype: int64

# %%
matches_df.query("(toss_decision == 'field' & winner == toss_winner)|(toss_decision == 'bat' & winner != toss_winner)")['winner'].value_counts()
# Out:
# Kolkata Knight Riders          54
# Mumbai Indians                 47
# Royal Challengers Bangalore    47
# Delhi Daredevils               42
# Chennai Super Kings            42
# Kings XI Punjab                41
# Rajasthan Royals               41
# Sunrisers Hyderabad            24
# Gujarat Lions                  12
# Deccan Chargers                11
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Rising Pune Supergiants         5
# Kochi Tuskers Kerala            4
# Name: winner, dtype: int64

# %%
deliveries_df = pd.read_csv("data/deliveries.csv")

# %%
deliveries_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over   ...    bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0   ...           0
# 1     2  DA Warner    S Dhawan  TS Mills              0   ...           0
# 2     3  DA Warner    S Dhawan  TS Mills              0   ...           0
# 3     4  DA Warner    S Dhawan  TS Mills              0   ...           0
# 4     5  DA Warner    S Dhawan  TS Mills              0   ...           0
#
# ...

# %%
deliveries_df.query("total_runs == 0")['batsman'].value_counts()
# Out:
# V Kohli              1280
# S Dhawan             1193
# G Gambhir            1170
# RG Sharma            1164
# RV Uthappa           1120
# SK Raina             1106
# CH Gayle             1101
# AM Rahane             998
# DA Warner             984
# BB McCullum           886
# JH Kallis             878
# MS Dhoni              871
# SR Watson             869
# KD Karthik            852
# M Vijay               844
# PA Patel              838
# Yuvraj Singh          835
# AB de Villiers        755
# R Dravid              746
# AT Rayudu             745
# MK Pandey             741
# DR Smith              738
# YK Pathan             727
# SR Tendulkar          725
# SE Marsh              647
# AC Gilchrist          628
# V Sehwag              601
# NV Ojha               581
# KA Pollard            576
# MEK Hussey            572
#                      ...
# M Wood                  2
# VS Malik                2
# SB Wagh                 2
# A Dananjaya             2
# ...

# %%
x = deliveries_df.groupby('batsman')['batsman_runs'].aggregate(sum)

# %%
x.sort_values(ascending=False)
# Out:
# batsman
# SK Raina             5014
# V Kohli              4962
# RG Sharma            4504
# G Gambhir            4223
# RV Uthappa           4144
# S Dhawan             4090
# MS Dhoni             4041
# CH Gayle             4037
# DA Warner            4014
# AB de Villiers       3974
# AM Rahane            3445
# KD Karthik           3423
# YK Pathan            3198
# SR Watson            3197
# AT Rayudu            3031
# BB McCullum          2893
# V Sehwag             2728
# Yuvraj Singh         2657
# M Vijay              2525
# MK Pandey            2522
# KA Pollard           2492
# SE Marsh             2489
# PA Patel             2482
# JH Kallis            2427
# DR Smith             2385
# SR Tendulkar         2334
# R Dravid             2174
# AC Gilchrist         2069
# JP Duminy            2041
# MEK Hussey           1977
#                      ...
# H Das                   2
# SB Wagh                 2
# DJ Muthuswami           1
# L Plunkett              1
# ...

# %%
deliveries_df.dismissal_kind.value_counts()
# Out:
# caught                   4861
# bowled                   1495
# run out                   813
# lbw                       494
# stumped                   262
# caught and bowled         211
# retired hurt               11
# hit wicket                  9
# obstructing the field       1
# Name: dismissal_kind, dtype: int64

# %%
deliveries_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
deliveries_df.query("dismissal_kind == 'run out'")['non_striker'].value_counts()
# Out:
# SK Raina            16
# KD Karthik          15
# RG Sharma           15
# AB de Villiers      14
# RV Uthappa          14
# YK Pathan           14
# M Vijay             13
# AM Rahane           12
# Yuvraj Singh        10
# S Dhawan            10
# G Gambhir           10
# PA Patel            10
# MS Dhoni            10
# SR Watson            9
# V Sehwag             8
# DJ Hussey            8
# P Kumar              8
# RA Jadeja            8
# Harbhajan Singh      8
# V Kohli              8
# IK Pathan            8
# SL Malinga           7
# F du Plessis         7
# PP Chawla            7
# BB McCullum          7
# JA Morkel            7
# AT Rayudu            7
# DPMD Jayawardene     7
# Y Venugopal Rao      7
# KH Pandya            7
#                     ..
# CJ Jordan            1
# AB Dinda             1
# K Gowtham            1
# Imran Tahir          1
# P Sahu               1
# DNT Zoysa            1
# MA Starc             1
# UT Khawaja           1
# SJ Srivastava        1
# ...

# %%
batsmen = deliveries_df.batsman.value_counts().index

# %%
non_strikers = deliveries_df.non_striker.value_counts().index

# %%
set(non_strikers) - set(batsmen)
# Out:
# {'A Nel', 'BW Hilfenhaus', 'C Ganapathy', 'TP Sudhindra'}

# %% [markdown]
# ![](https://memegenerator.net/img/instances/500x/73988569/pythonpandas-is-easy-import-and-go.jpg)
